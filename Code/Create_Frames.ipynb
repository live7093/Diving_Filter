# %% [markdown]
# # Quick ipynb to create a few frames from my diving videos

# %% [markdown]
# I created this ipynb to be able to create frames from my diving video with the help of ChatGPT

# %%
import cv2 as cv
import os

# %% [markdown]
# We ca now add our videos via video_xy = path and then create frames with a defined intervall of frames to a predefined folder

# %%
def create_frames(frame_interval, video_path, name):
    output_folder = '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/created_frames'
    os.makedirs(output_folder, exist_ok=True)

    cap = cv.VideoCapture(video_path)
    frame_idx = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if frame_idx % frame_interval == 0:
            frame_filename = os.path.join(output_folder, f'{name}_{frame_idx:04d}.jpg')
            cv.imwrite(frame_filename, frame)

        frame_idx += 1

    cap.release()
    print(f"✅ Done! Extracted {frame_idx//frame_interval} images as '{name}_xxxx.jpg' to '{output_folder}/'")

# %%
create_frames(90, video_1, name= "Video_1")
# Out:
# Done! Extracted 14 images to '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/created_frames/'

# %% [markdown]
# Now that it works I can create a quick way to create all the frames for all the videos

# %%
#  video paths:


video_1 = '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/Videos/DJI_20240831115119_0024_D.MP4'
video_2 = '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/Videos/DJI_20240902131302_0094_D.MP4' #3-4m Video
video_3 = '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/Videos/DJI_20240908123049_0155_D.MP4' #27m Video
video_4 = '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/Videos/DJI_20240909142011_0216_D.MP4' #20-25m Video
video_5 = '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/Videos/DJI_20240902110915_0068_D.MP4' #10m? maybe

# %%
# create_frames(90, video_1, name= "Video_1")
# Out:
# ✅ Done! Extracted 14 images as 'Video_1_xxxx.jpg' to '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/created_frames/'

# %%
video_paths = [video_1, video_2, video_3, video_4, video_5]
names = ["Video_1", "Video_2", "Video_3", "Video_4", "Video_5"]

for path, name in zip(video_paths, names):
    create_frames(90, path, name)
# Out:
# ✅ Done! Extracted 14 images as 'Video_1_xxxx.jpg' to '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/created_frames/'
# ✅ Done! Extracted 10 images as 'Video_2_xxxx.jpg' to '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/created_frames/'
# ✅ Done! Extracted 22 images as 'Video_3_xxxx.jpg' to '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/created_frames/'
# ✅ Done! Extracted 17 images as 'Video_4_xxxx.jpg' to '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/created_frames/'
# ✅ Done! Extracted 22 images as 'Video_5_xxxx.jpg' to '/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/created_frames/'
