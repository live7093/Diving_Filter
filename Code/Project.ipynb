# %% [markdown]
# # Filter for diving photos

# %% [markdown]
# Inhaltsverzeichnis

# %% [markdown]
# At first we import the liberary

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import PIL

# %% [markdown]
# Via the Create_Frames.ipynb we are able to create pictures from Ruben diving videos from Egypt 2024 those frames are saved and we selected a few good ones.

# %%
#Define the path to the folder containing the images
folder ='/Users/rubenschmid/Desktop/ZHAW/4.Semester/Image und Signal Processing/Image-and-Signal-Processing Ruben/Diving_Filter/Video_to_frames/created_frames'

# Load the selected frames
picture_1 = cv.imread(folder + '/frame_0.jpg')
picture_2 = cv.imread(folder + '/frame_1.jpg')
picture_3 = cv.imread(folder + '/frame_2.jpg')
